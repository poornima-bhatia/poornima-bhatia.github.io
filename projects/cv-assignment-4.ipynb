# %% [markdown]
# ---
# title: Computer Vision <code>assignment-4</code>
# descrption: Computer Vision Assignment-4
# author: Poornima Bhatia
# date: 'November 21, 2024'
# categories: ['Optical Flow']
# image: True
# foramt:
# html:
# code-fold: true
# ---

# %% [markdown]
# [📓 View the Optical Flow Notebook](https://github.com/poornima-bhatia/computer-vision/blob/main/optical-flow/main.ipynb)
