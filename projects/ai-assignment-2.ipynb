# %% [markdown]
# ---
# title: Artificial Intelligence <code>assignment-2</code>
# descrption: Artificial Intelligence Assignment-2
# author: Poornima Bhatia
# date: 'Feburary 06, 2024'
# categories: ['DFS','BFS']
# # image: False
# foramt:
# html:
# code-fold: true
# ---

# %% [markdown]
# A farmer is on one side of a river and wishes to cross the river with a wolf, a chicken, and a bag of grain. He can only take one item at a time in his boat with him. He must be in the boat in order for it to cross the river. He cannot leave the chicken alone with the grain, or it will eat the grain. (Note: the chicken will not eat the grain if the farmer is on that side of the river, either in the boat or on shore.) He cannot leave the wolf alone with the chicken or the wolf will eat the chicken.

# %% [markdown]
#  <iframe src="../assets/pdf/assignment-2-answer.pdf" width="100%" height="500px"></iframe>

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# ### Depth First Search

# %% [markdown]
# ![](attachment:dfs.png)

# %% [markdown]
# ### Breadth First Search

# %% [markdown]
# ![](attachment:bfs.png)

# %% [markdown]
# ### Problem Solution Tree

# %% [markdown]
# ![](attachment:problem-solution-tree-0.png)
