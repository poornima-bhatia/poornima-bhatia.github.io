# %% [markdown]
# ---
# title: Computer Vision <code>assignment-3</code>
# descrption: Computer Vision Assignment-3
# author: Poornima Bhatia
# date: 'October 11, 2024'
# categories: ['Panaroma Stitching']
# image: True
# foramt:
# html:
# code-fold: true
# ---

# %% [markdown]
# Homography matrices and stitch images to make a Panaroma

# %% [markdown]
# ### Given a set of images, Find Homography matrices and stitch images to make a Panaroma.

# %% [markdown]
# <iframe src="../assets/pdf/cv-assignment-3-answer.pdf" width="100%" height="500px"></iframe>
